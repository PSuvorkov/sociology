# %% [markdown]
# Устанавливаем библиотеки: pandas - для работы с таблицами, pyreadstat - для чтения файлов из статистических программ (типа SPSS). Обязательно указываем версию библиотеки через ==, потому что код, работающий в одной версии, может не работать в другой.
# Документации на них:
#
# https://pandas.pydata.org
#
# https://ofajardo.github.io/pyreadstat_documentation/_build/html/index.html

# %%
# !pip install pandas==1.4.2 pyreadstat==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 40.9 MB/s eta 0:00:00
# Collecting pyreadstat==1.2.0
#   Downloading pyreadstat-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 43.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.2) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.2) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.16.0)
# Installing collected packages: pandas, pyreadstat
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# Successfully installed pandas-1.4.2 pyreadstat-1.2.0

# %% [markdown]
# Подключаем Google Disk, надо будет дать разрешение этой jupyter-notebook тетрадке на чтение/запись с него. Файлы *.sav должны быть заранее загружены на Google Disk. Если они загружены не в корень диска, а в подпапку, надо будет поменять переменные fpath (cм. ниже)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# импортируем библиотеку pyreadstat, 
# которая ориентирована на работу с форматами статистических (в т.ч., платных) программ.
import pyreadstat
import numpy as np

# %%
# В программе учебной дисциплины заявлен анализ по 2011 году, но в данных по нему нет нужных нам переменных.

# Источник данных: https://gks.ru/ .

fpath_2020 = 'drive/MyDrive/коуж/IND_OSN_2020.sav'
df_2020, meta_2020 = pyreadstat.read_file_multiprocessing(pyreadstat.read_sav, fpath_2020, num_processes=16, encoding='cp1251') 
meta_2020.column_names_to_labels
# Out:
# {'H00_02': 'Код субъекта РФ',
#  'H00_04': 'Тип населенного пункта',
#  'H00_06': 'Номер домохозяйства',
#  'H01_00': 'Индивидуальный код члена домохозяйства',
#  'H00_07': 'Тип населенного пункта по численности населения',
#  'H01_01': 'Пол',
#  'H01_02': 'Число исполнившихся лет',
#  'H01_03': 'Родственное отношение',
#  'H01_04': 'Семейное положение',
#  'H01_05': 'C какого времени семейное положение такое',
#  'H01_06': 'Индивидуальный код супруга',
#  'H01_07': 'Проживание в домохозяйстве',
#  'H01_08': 'Проживание на день опроса',
#  'H01_09': 'Причина отсутствия на момент опроса',
#  'H01_10': 'Возможность дать информацию о самом себе',
#  'H01_11': 'Причина, по которой респондент не может дать сам о себе информацию',
#  'H01_12': 'Код лица, ответившего за респондента',
#  'H01_13': 'Тип семейной единицы',
#  'H01_14': 'Порядковый номер семейной единицы в домохозяйстве',
#  'I00_09': 'Число проведения опроса',
#  'I00_10': 'Месяц проведения опроса',
#  'I00_11': 'Год проведения опроса',
#  'I00_12': 'Час начала опроса',
#  'I00_13': 'Минуты начала опроса',
#  'I00_14': 'Час окончания опроса',
#  'I00_15': 'Минуты окончания опроса',
#  'I01_01': 'Семейное положение',
#  'I01_02': 'Проживание супругов',
#  'I01_03': 'Причина раздельного проживания супругов',
#  'I01_04': 'Наличие детей проживающих отдельно',
#  'I01_05_01': 'Дети проживают в том же населенном пункте',
#  'I01_05_02': 'Дети проживают в другом населенном пункте, в другом субъекте РФ',
#  'I01_05_03': 'Дети проживают в другой стране',
#  'I01_05_04': 'Нет сведений о месте проживания детей',
#  'I01_05_05': 'Отказ от ответа о проживании детей',
#  'I01_06_01': 'Число детей респондента в возрасте до 18 лет, проживающих отдельно',
#  'I01_06_02': 'Число детей респондента в возрасте 18 лет и более, проживающих отдельно',
#  'I01_06_03': 'Отказ от ответа об общем числе детей, проживающих отдельно',
#  'I01_07_01': 'Дети, проживающие отдельно оказывают денежную помощь',
#  'I01_07_02': 'Дети, проживающие отдельно помогают по хозяйству',
#  'I01_07_03': 'Дети, проживающие отдельно покупают продукты, вещи',
#  'I01_07_04': 'Дети, проживающие отдельно ухаживают во время болезни',
#  'I01_07_05': 'Дети, проживающие отдельно оказывают другую помощь',
#  'I01_08_01': 'Не оказывают помощь родителям из-за отсутствия материальной возможности',
#  'I01_08_02': 'Не оказывают помощь родителям по состоянию здоровья',
#  'I01_08_03': 'Не оказывают помощь родителям из-за нехватки времени',
#  'I01_08_04': 'Не поддерживают отношений с родителями',
#  'I01_08_05': 'Затруднились ответить',
#  'I01_08_06': 'Отказались от ответа',
#  'I01_09_01': 'Оказание денежной помощи своим детям',
#  'I01_09_02': 'Помощь в обеспечении продуктами своим детям',
#  'I01_09_03': 'Покупка вещей своим детям',
#  'I01_09_04': 'Оплата жилья своим детям',
#  'I01_09_05': 'Помощь в воспитании (в т.ч.. внуков) своим детям',
#  'I01_09_06': 'Помощь по хозяйству, на садовом (дачном) участке своим детям',
#  'I01_09_07': 'Уход во время болезни своим детям',
#  'I01_09_08': 'Оказание другой помощи своим детям',
#  'I01_09_09': 'Не оказание помощи своим детям',
#  'I01_09_10': 'Нет необходимости в помощи своим детям',
#  'I01_09_11': 'Затруднились ответить об оказании помощи своим детям',
#  'I01_09_12': 'Отказались от ответа о помощи своим детям',
#  'I01_10_01': 'Есть человек, с кем можно обсудить вопросы личного характера',
#  'I01_10_02': 'В случае необходимости, можно просить о помощи человека, который не является членом домохозяйства',
#  'I01_10_03': 'Встречаются с друзьями, родственниками или коллегами, хотя бы, раз в неделю',
#  'I02_01_01': 'В своем населенном пункте респондент проживает с рождения',
#  'I02_01_02': 'С какого года проживает в данном населенном пункте',
#  'I02_02': 'Мнение о проживании в населенном пункте',
#  'I02_03_01': 'Существование в населенном пункте высокого уровня преступности (нарушения общественного порядка)',
#  'I02_03_02': 'Недоступность государственных и муниципальных услуг в сфере медицинского обслуживания в населенном пункте',
#  'I02_03_03': 'Недоступность государственных и муниципальных услуг в сфере дошкольного и школьного образования в населенном пункте',
#  'I02_03_031': 'Недоступность государственных и муниципальных услуг в сфере оформления документов по запросам населения',
#  'I02_03_04': 'Большая отдаленность торговых точек в населенном пункте',
#  'I02_03_05': 'Большая отдаленность аптек в населенном пункте',
#  'I02_03_06': 'Большая отдаленность учреждений культуры в населенном пункте',
#  'I02_03_07': 'Большая отдаленность  мест проведения отдыха и досуга в населенном пункте',
#  'I02_03_08': 'Большая отдаленность объектов для занятий физкультурой и спортом в населенном пункте',
#  'I02_03_09': 'Плохая организация жилищно-коммунальных служб в населенном пункте',
#  'I02_03_10': 'Плохая организация работы общественного транспорта',
#  'I02_03_11': 'Общая неблагоустроенность, недостаточность озеленения в населенном пункте',
#  'I02_03_12': 'Существуют проблемы с состоянием дорог, безопасностью дорожного движения в населенном пункте',
#  'I02_03_13': 'Вандализм (умышленные разрушения в общественных местах и жилых домах) в населенном пункте',
#  'I02_03_14': 'Распространение наркотиков в населенном пункте',
#  'I02_03_15': 'Распространение алкоголизма в населенном пункте',
#  'I02_03_16': 'Загрязненность окружающей среды в населенном пункте',
#  'I02_03_17': 'Другие проблемы в населенном пункте',
#  'I03_01_01': 'Регулярное использование общественного городского (пригородного) муниципального транспорта',
#  'I03_01_02': 'Регулярное использование общественного городского (пригородного) коммерческого транспорта',
#  'I03_01_03': 'Регулярное использование электропоезда, пригородного поезда',
#  'I03_01_041': 'Регулярное использование собственного автомобиля, мотоцикла (в качестве водителя)',
#  'I03_01_042': 'Регулярное использование арендованного (каршеринг) автомобиля, мотоцикла (в качестве водителя)',
#  'I03_01_05': 'Регулярное использование автомобиля, мотоцикла (в качестве пассажира)',
#  'I03_01_06': 'Регулярное использование такси (включая частный извоз на легковых автомобилях)',
#  'I03_01_07': 'Регулярное использование автомобиля, предоставляемого работодателем',
#  'I03_01_08': 'Регулярное использование мопеда, велосипеда и др.',
#  'I03_01_09': 'Регулярное использование гужевого, водного транспорта',
#  'I03_01_10': 'Регулярное использование другого вида транспорта',
#  'I03_01_11': 'Код наиболее часто используемого вида транспорта',
#  'I03_01_12': 'Респондент не пользуется транспортом',
#  'I03_02_01': 'Количество поездок используемых в течение последнего месяца',
#  'I03_02_02': 'Время (в среднем за одну поездку) на ожидание транспорта, минут',
#  'I03_02_03': 'Время (в среднем за одну поездку) на поездку, минут',
#  'I03_05': 'Наличие другой возможности добраться до нужного места, при сбое в работе общественного транспорта',
#  'I04_01_01': 'Удовлетворенность условиями торгового обслуживания вблизи дома',
#  'I04_01_02': 'Удовлетворены условиями бытового обслуживания вблизи дома',
#  'I04_02_01_01': 'Плохой ассортимент в торговом обслуживании',
#  'I04_02_01_02': 'Плохое качество товара в торговом обслуживании',
#  'I04_02_01_03': 'Уровень цен выше, чем в других местах в торговом обслуживанием',
#  'I04_02_01_04': 'Большие очереди, неудобный режим работы в торговом обслуживании',
#  'I04_02_01_05': 'Другая причина не удовлетворенности торговым обслуживанием',
#  'I04_02_01_06': 'Затруднились ответить о торговом обслуживании',
#  'I04_02_02_01': 'Плохой ассортимент бытового обслуживания',
#  'I04_02_02_02': 'Плохое качество товара  бытового обслуживания',
#  'I04_02_02_03': 'Уровень цен выше, чем в других местах  бытового обслуживания',
#  'I04_02_02_04': 'Большие очереди, неудобный режим работы бытового обслуживания',
#  'I04_02_02_05': 'Другая причина неудовлетворенности бытовым обслуживанием',
#  'I04_02_02_06': 'Затруднились ответить о бытовом обслуживании',
#  'I04_03_01': 'Приобретение продуктов питания, средств личной гигиены',
#  'I04_03_02': 'Приобретение одежды, обуви',
#  'I04_03_03': 'Приобретение бытовой техники, радиоэлектронной аппаратуры, средств связи и др.',
#  'I04_04_01': 'Использование Интернет или почты при покупке продуктов питания, средств личной гигиены',
#  'I04_04_02': 'Использование Интернет или почты при покупке одежды, обуви',
#  'I04_04_03': 'Использование Интернет или почты при покупке бытовой техники',
#  'I05_01': 'Наличие на прошлой неделе оплачиваемой работы или доходного занятия',
#  'I05_02': 'Наличие на прошлой неделе работы в фермерском хозяйстве или в собственном деле без оплаты',
#  'I05_03': 'Наличие на прошлой неделе работы или собственного дела, на котором отсутствовали',
#  'I05_031': 'Наличие оформленного отпуска по уходу за ребенком в возрасте до 1,5 (до 3 лет)',
#  'I05_04': 'Основная работа',
#  'I05_06': 'Работали в качестве',
#  'I05_07': 'На каких условиях работали',
#  'I05_08': 'Режим работы',
#  'I05_09': 'Условия деятельности предприятия',
#  'I05_10': 'Код профессии/занятия',
#  'I05_11': 'Соответствие основной работы с полученной специальностью',
#  'I05_12': 'Наличие специальной профессиональной подготовки для нынешней работы',
#  'I05_14': 'Наличие навыков или квалификации для выполнения более сложной работы',
#  'I05_141': 'Использование компьютерной техники на основной работе, хотя бы, один раз в неделю',
#  'I05_15': 'Потребность в получении знаний в области информационных технологий',
#  'I05_151': 'Позволяет ли характер работы выполнять ее дистанционно, через Интернет',
#  'I05_152': 'Возможность работать дистанционно, через Интернет',
#  'I05_153': 'Принимает участие в организованных программах наставничества или обучения',
#  'I05_16': 'Характеристика основной работы с точки зрения физических затрат на ее выполнение',
#  'I05_17_01': 'Работа связана с нервным напряжением',
#  'I05_17_02': 'Воздействие вредных производственных факторов на рабочем месте',
#  'I05_17_03': 'Существование других неудобств на рабочем месте',
#  'I05_171': 'Мнение о безопасности работы с точки зрения вероятности несчастного случая',
#  'I05_172': 'Наличие несчастного случая на производстве за последние 12 месяцев',
#  'I05_18': 'Количество часов в неделю отработанных на основной работе, включая сверхурочную работу',
#  'I05_20_01': 'Степень удовлетворенности заработной платой',
#  'I05_20_02': 'Степень удовлетворенности надежностью работы',
#  'I05_20_03': 'Степень удовлетворенности выполняемыми обязанностями',
#  'I05_20_04': 'Степень удовлетворенности режимом работы',
#  'I05_20_05': 'Степень удовлетворенности условиями труда',
#  'I05_20_06': 'Степень удовлетворенности расстоянием до работы',
#  'I05_20_07': 'Профессиональная удовлетворенность',
#  'I05_20_08': 'Моральное удовлетворение в работе',
#  'I05_24': 'Полнота работы за весь период в этом году на основной и дополнительной работе',
#  'I05_25': 'В период, когда респондент не работал, он…',
#  'I05_251': 'Находился в вынужденном отпуске или не работал по болезни',
#  'I05_26_01_01': 'Год ухода в отпуск по уходу за ребенком',
#  'I05_26_01_02': 'Месяц ухода в отпуск по уходу за ребенком',
#  'I05_26_02': 'Месяц окончания отпуска по уходу за ребенком',
#  'I05_26_03': 'Отказ от ответа',
#  'I05_27': 'Возвращение на прежнее место работы',
#  'I05_28': 'Причина смены работы',
#  'I05_29': 'Описание положения в занятости в этом году',
#  'I05_30': 'Регистрация в службе занятости населения',
#  'I05_31': 'Наличие оплачиваемой работы до начала этого года',
#  'I05_37': 'Поиск подходящей работы',
#  'I05_38': 'Вид работы, которую ищет респондент',
#  'I05_39': 'Предпочтительное время работы',
#  'I05_40': 'Наличие реальной возможности найти подходящую работу в ближайшее время',
#  'I05_41': 'Входит ли в круг ежедневных занятий уход за детьми',
#  'I05_43': 'Ухаживают за нуждающимися в особой помощи лицами, проживающими в домохозяйстве',
#  'I06_01': 'Получение пенсии',
#  'I06_02_01': 'Вид назначенной пенсии (первая пенсия)',
#  'I06_02_02': 'Вид назначенной пенсии (вторая пенсия)',
#  'I06_03_01': 'Год назначения пенсии',
#  'I06_03_02': 'Месяц назначения пенсии',
#  'I06_05_01': 'Наличие необходимости обратиться в Пенсионный фонд РФ',
#  'I06_05_02': 'Наличие необходимости обратиться в органы социальной защиты населения',
#  'I06_05_03': 'Наличие необходимости обратиться в отделение Фонда социального страхования',
#  'I06_05_04': 'Наличие необходимости обратиться в службу занятости',
#  'I06_05_05': 'Не было необходимости обращения',
#  'I06_06_01_01': 'Своевременность обращения в Пенсионный Фонд',
#  'I06_06_01_02': 'Обращение в Пенсионный Фонд через сеть',
#  'I06_06_02_01': 'Своевременность обращения в органы социальной защиты населения',
#  'I06_06_02_02': 'Обращение в органы социальной защиты населения через сеть',
#  'I06_06_03_01': 'Своевременность обращения в отделение Фонда социального страхования',
#  'I06_06_03_02': 'Обращение в отделение Фонда социального страхования через сеть',
#  'I06_06_04_01': 'Своевременность обращения в в службу занятости',
#  'I06_06_04_02': 'Обращение в службу занятости через сеть',
#  'I06_07_01': 'Отсутствие необходимой информации о работе этих учреждений',
#  'I06_07_02': 'Неудобный график работы учреждений',
#  'I06_07_03': 'Дорогой транспорт на поездку в эти учреждения',
#  'I06_07_04': 'Введение карантинных мер',
#  'I06_07_05': 'Отсутствие технических устройств для выхода в Интернет',
#  'I06_07_06': 'Отсутствие мобильной связи и сети «Интернет»,  в т.ч. перебои в их работе',
#  'I06_07_07': 'По другим причинам',
#  'I07_01': 'Уровень образования',
#  'I07_02': 'Наличие профессии, подтвержденной дипломом',
#  'I07_03_01': 'Специальность 1, по которой получено образование',
#  'I07_03_02': 'Специальность 2, по которой получено образование',
#  'I07_03_03': 'Специальность 3, по которой получено образование',
#  'I07_04': 'Суммарное количество лет, затраченное на образование',
#  'I07_05': 'Обучение в настоящее время',
#  'I07_06': 'Какое образование получают в настоящее время',
#  'I07_07': 'Посещение общеобразовательной организации',
#  'I07_09_01': 'Тип общеобразовательной организации',
#  'I07_09_02': 'Класс, в котором учится респондент',
#  'I07_10_01_01': 'Имеется компьютерный класс',
#  'I07_10_01_02': 'Частота пользования компьютерным классом',
#  'I07_10_02_01': 'Имеется доступ к сети Интернет',
#  'I07_10_02_02': 'Частота пользования доступом к сети Интернет',
#  'I07_10_03_01': 'Имеется собственный сайт',
#  'I07_10_03_02': 'Частота пользования собственным сайтом',
#  'I07_10_04_01': 'Имеется электронный дневник учащегося',
#  'I07_10_04_02': 'Частота пользования электронным дневником учащегося',
#  'I07_10_05_01': 'Имеется программа с использованием дистанционных технологий',
#  'I07_10_05_02': 'Частота пользования программой с использованием дистанционных технологий',
#  'I07_10_06_01': 'Имеются интерактивные доски',
#  'I07_10_06_02': 'Частота пользования интерактивными досками',
#  'I07_10_07_01': 'Имеется электронная библиотека',
#  'I07_10_07_02': 'Частота пользования электронной библиотекой',
#  'I07_10_08_01': 'Имеется библиотека',
#  'I07_10_08_02': 'Частота пользования библиотекой',
#  'I07_10_09_01': 'Имеется спортзал',
#  'I07_10_09_02': 'Частота пользования спортзалом',
#  'I07_10_10_01': 'Имеется бассейн',
#  'I07_10_10_02': 'Частота пользования бассейном',
#  'I07_11_01': 'Посещение дополнительных факультативных занятий или занятий по специальной программе',
#  'I07_11_02': 'Посещение дополнительных занятий с репетитором для повышения уровня успеваемости',
#  'I07_11_03': 'Посещение дополнительных занятий центра дополнительного образования',
#  'I07_11_04': 'Посещение дополнительных занятий музыкальной школы',
#  'I07_11_05': 'Посещение дополнительных занятий центра детского творчества, технической секции',
#  'I07_11_06': 'Посещение дополнительных занятий спортивных школ и секций',
#  'I07_11_07': 'Посещение дополнительных занятий курсов иностранного языка',
#  'I07_11_08': 'Посещение дополнительных занятий информатикой и программированием, изучением и конструированием техники',
#  'I07_11_09': 'Посещение дополнительных занятий учебного центра обучения на производстве',
#  'I07_11_10': 'Ничего из перечисленного не посещал',
#  'I07_14': 'Форма обучения',
#  'I07_15': 'Плата за обучение по базовой программе',
#  'I07_16': 'Место нахождения образовательной организации',
#  'I07_17_01': 'Занятие 1 в свободное время',
#  'I07_17_02': 'Занятие 2 в свободное время',
#  'I07_17_03': 'Занятие 3 в свободное время',
#  'I07_18': 'Намерения по продолжению обучения',
#  'I07_19': 'Вид образовательной организации, в которой респондент намеревается продолжить обучение',
#  'I07_20_01': 'Посещение подготовительных курсов с целью подготовки поступления в образовательную организацию',
#  'I07_20_02': 'Занятия с репетитором с целью подготовки поступления в образовательную организацию',
#  'I07_20_03': 'Не посещают дополнительных занятий с целью подготовки поступления в образовательную организацию',
#  'I07_20_04': 'Затруднились с ответом',
#  'I07_201': 'Форма обучения на подготовительных курсах или занятия с репетитором',
#  'I07_21': 'Обучение по программам дополнительного образования за последние 12 месяцев',
#  'I07_22_01': 'Обучение по линии службы занятости',
#  'I07_22_02': 'Обучение по общей или специальной образовательной программе в образовательной организации',
#  'I07_22_03': 'Обучение, организованное по месту работы (работодателем)',
#  'I07_22_04': 'Обучение в организации сетевого маркетинга',
#  'I07_22_05': 'Участие в образовательных проектах, тематических курсах, тренингах',
#  'I07_22_06': 'Обучение по индивидуальной программе (индивидуальные занятия с репетитором)',
#  'I07_22_07': 'Обучение в сетевых образовательных сообществах, самостоятельное обучение с использованием сети Интернет',
#  'I07_22_08': 'Самообразование с использованием печатных материалов, аудиозаписей, передач по телевидению и т.п.',
#  'I07_221_01': 'Получение новой профессии',
#  'I07_221_02': 'Повышение квалификации',
#  'I07_221_03': 'Применение новых информационных технологий (по месту работы, в интересах собственного дела)',
#  'I07_221_04': 'Изучение иностранных языков',
#  'I07_221_05': 'Повышение компьютерной грамотности, изучение компьютерных программ, Интернет-сервисов',
#  'I07_221_06': 'Повышение финансовой грамотности, освоение инструментов финансового рынка',
#  'I07_221_07': 'Обучение вождению автомобиля (для получения любительских прав)',
#  'I07_221_08': 'Расширение кругозора, развитие творческих, физических и деловых способностей',
#  'I07_221_09': 'Другое направление',
#  'I07_222_01': 'Обучение за последние 12 месяцев в очной форме',
#  'I07_222_021': 'Обучение за последние 12 месяцев в дистанционной форме (с использованием сети Интернет, мобильных устройств: видео- и аудиолекции, электронн',
#  'I07_222_022': 'Обучение за последние 12 месяцев в дистанционной форме (с использованием сети Интернет, мобильных устройств: в формате on-line занятий с препод?',
#  'I07_23': 'Желание заняться вновь или дополнительно обучением по подходящей программе',
#  'I07_24_01': 'Направление 1, по которому хотят получить образование',
#  'I07_24_02': 'Направление 2, по которому хотят получить образование',
#  'I07_24_03': 'Направление 3, по которому хотят получить образование',
#  'I08_04': 'Частота выходов в сеть Интернет',
#  'I08_05_01': 'Цели выхода в сеть Интернет: выполнение оплачиваемой работы',
#  'I08_05_02': 'Цели выхода в сеть Интернет: поиск вакансий, клиентов, рассылка информации',
#  'I08_05_03': 'Цели выхода в сеть Интернет: получение информации, оформление документов на сайтах органов государственной власти',
#  'I08_05_04': 'Цели выхода в сеть Интернет: поиск и заказ товаров и услуг, продажа личных вещей и имущества',
#  'I08_05_05': 'Цели выхода в сеть Интернет: осуществление финансовых операций',
#  'I08_05_06': 'Цели выхода в сеть Интернет: дистанционное обучение',
#  'I08_05_07': 'Цели выхода в сеть Интернет: пользование электронными библиотеками, энциклопедиями, виртуальными экскурсиями и др.',
#  'I08_05_08': 'Цели выхода в сеть Интернет: прочтение новостной информации',
#  'I08_05_09': 'Цели выхода в сеть Интернет: общение в социальных сетях',
#  'I08_05_10': 'Цели выхода в сеть Интернет: обсуждение социальных и политических вопросов',
#  'I08_05_11': 'Цели выхода в сеть Интернет: скачивание фильмов, музыки, игр и др.',
#  'I08_05_12': 'Цели выхода в сеть Интернет: другие',
#  'I08_07': 'Частота общения с людьми через Интернет',
#  'I09_01_01': 'Совершали поездку продолжительностью менее суток за последние 12 месяцев',
#  'I09_01_02': 'Совершали поездку продолжительностью более суток за последние 12 месяцев',
#  'I09_01_03': 'Не совершали туристских или экскурсионных поездок за последние 12 месяцев',
#  'I09_01_04': 'Никогда не совершали туристских или экскурсионных поездок',
#  'I09_01_05': 'Затруднились ответить, совершали ли туристские или экскурсионные поездки',
#  'I09_01_06': 'Год последней туристской или экскурсионной поездки',
#  'I09_011_01': 'Совершали за последние 12 месяцев туристские или экскурсионные поездки по Российской Федерации',
#  'I09_011_02': 'Совершали за последние 12 месяцев туристские или экскурсионные поездки за пределы Российской Федерации',
#  'I09_012_01': 'Цель поездки: отдых, оздоровление, санаторно-курортного лечение, лечение заболеваний и т.п.',
#  'I09_012_02': 'Цель поездки: познавательная, экскурсионная или культурно-развлекательная (включая водные путешествия)',
#  'I09_012_03': 'Цель поездки: паломничество (посещение святых мест для поклонения)',
#  'I09_012_04': 'Цель поездки: участие (посещение) в научных форумах, выставках (ярмарках), поездки с целью обучения',
#  'I09_012_05': 'Цель поездки: посещение спортивных мероприятий в качестве участника или болельщика',
#  'I09_012_06': 'Цель поездки: походные туры (экспедиции), альпинизм, горные лыжи, яхтинг и т.п.',
#  'I09_012_07': 'Цель поездки: поездки к родителям, родственникам или к друзьям, к родным местам',
#  'I09_012_08': 'Цель поездки: поездки на дачу, охоту, рыбалку, поездки для сбора грибов, ягод',
#  'I09_012_09': 'Цель поездки: посещение особо охраняемых природных, экологически чистых территорий, агроферм и т.п.',
#  'I09_02': 'Причина отказа от туристских или экскурсионных поездок',
#  'I09_03_01_01': 'Были  в кино',
#  'I09_03_01_02': 'Частота посещений кино',
#  'I09_03_02_01': 'Были в театре',
#  'I09_03_02_02': 'Частота посещений театра',
#  'I09_03_03_01': 'Были на концерте',
#  'I09_03_03_02': 'Частота посещений концертов',
#  'I09_03_04_01': 'Были в музее, на выставке',
#  'I09_03_04_02': 'Частота посещений музеев, выставок',
#  'I09_03_05_01': 'Были в ресторане, кафе',
#  'I09_03_05_02': 'Частота посещений ресторанов, кафе',
#  'I09_03_06_01': 'Были в религиозном учреждении или на встрече верующих',
#  'I09_03_06_02': 'Частота посещений религиозного учреждения или встречи верующих',
#  'I09_03_07_01': 'Были на спортивном мероприятии в качестве зрителя',
#  'I09_03_07_02': 'Частота посещений спортивных мероприятий',
#  'I09_04': 'Членство в добровольных организациях',
#  'I09_05_01': 'Участие в деятельности профсоюзной организации',
#  'I09_05_02': 'Участие в деятельности политических партий, массовых молодежных объединений, женских союзов, обществ инвалидов и т.п.',
#  'I09_05_03': 'Участие в деятельности творческих союзов, добровольных обществ, ассоциаций профессиональных работников и т.п.',
#  'I09_05_04': 'Участие в деятельности религиозных организаций',
#  'I09_05_05': 'Участие в деятельности общественных комитетов (советов) при органах госуправления (местного самоуправления) и т.п.',
#  'I09_05_06': 'Участие в деятельности общественных самодеятельных политических, социальных, экологических движений',
#  'I09_05_07': 'Участие в деятельности общественных инициативных движений, групп по формированию комфортной городской среды',
#  'I09_05_08': 'Участие в деятельности неформальных объединений (по любительским увлечениям, интересам и т.п.)',
#  'I09_05_09': 'Участие в деятельности волонтерских движений (организаций)',
#  'I09_051': 'Периодичность участия в деятельности добровольных организаций',
#  'I09_06': 'Возможность вести активную жизнь',
#  'I09_07_01': 'Посещают организованные занятия в спортивной секции (спортивной школе)',
#  'I09_07_02': 'Посещают абонементные занятия плаванием, фитнесом и т.п.',
#  'I09_07_03': 'Занимаются силовыми тренировками, спортивными танцами, игрой в хоккей, футбол, другими видами активного отдыха',
#  'I09_07_04': 'Не занимаются спортом и активными видами отдыха',
#  'I09_071_01': 'Занимаются спортом или активными видами отдыха почти каждый день',
#  'I09_071_02': 'Занимаются спортом или активными видами отдыха несколько раз в неделю, по выходным',
#  'I09_071_03': 'Занимаются спортом или активными видами отдыха несколько раз в месяц или реже',
#  'I09_08': 'Причина отказа от занятий спортом и активными видами отдыха',
#  'I09_081_01': 'Занимаются в свободное время живописью, прикладным творчеством, кино-фото-видеосъемкой и т.п.',
#  'I09_081_02': 'Занимаются в свободное время литературным творчеством, театральным искусством и т.п.',
#  'I09_081_03': 'Занимаются в свободное время музыкой, пением, танцами и т.п.',
#  'I09_081_04': 'Не занимаются в свободное время перечисленными видами творчества',
#  'I09_09': 'Оценка безопасности района проживания респондента в темное время суток',
#  'I10_01': 'Самооценка состояния здоровья',
#  'I10_02': 'Наличие хронической болезни, установленной врачом',
#  'I10_07': 'Наличие установленной инвалидности в настоящее время',
#  'I10_071': 'Вид ограничения жизнедеятельности (по которому назначена инвалидность)',
#  'I10_13': 'Обращение за амбулаторной помощью в этом году',
#  'I10_17': 'Получение медицинской помощи',
#  'I10_18': 'Причины неполучения медицинской помощи',
#  'I10_19_01': 'Время на запись к врачу',
#  'I10_19_02': 'Время на ожидание приема врача',
#  'I10_21': 'Вызов скорой помощи',
#  'I10_23': 'Время ожидания скорой помощи',
#  'I10_23_02': 'Скорая помощь не приехала',
#  'I10_24': 'Случаи госпитализации',
#  'I10_241': 'Наличие трудностей при необходимости попасть в стационар',
#  'I10_242_01': 'Был увеличен срок ожидания плановой госпитализации',
#  'I10_242_02': 'Не было свободных мест',
#  'I10_242_03': 'Стационар был закрыт на карантин',
#  'I10_242_04': 'Другие проблемы',
#  'I10_26_01': 'Ожидание госпитализации',
#  'I10_26_02': 'Количество дней ожидания приема в больницу на госпитализацию',
#  'I10_27': 'Наличие потребности в медицинской помощи, но не обращались за ней',
#  'I10_29_01': 'Не рассчитываю на эффективное лечение',
#  'I10_29_02': 'Не удовлетворяет работа медорганизации',
#  'I10_29_03': 'Не могу добраться до медорганизации без посторонней помощи',
#  'I10_29_04': 'Было тяжело добраться до медорганизации',
#  'I10_29_05': 'Не располагал информацией о том, где можно получить необходимую помощь',
#  'I10_29_06': 'Не было времени',
#  'I10_29_07': 'Необходимое лечение можно получить только на платной основе',
#  'I10_29_08': 'Лечился сам',
#  'I10_29_09': 'Другие причины',
#  'I10_30_01': 'Обращение за консультацией медицинских работников без посещения медорганизации',
#  'I10_30_02': 'Обращение за помощью к народным целителям, гомеопатам, знахарям, экстрасенсам',
#  'I10_30_03': 'Не обращались ни за какой медицинской помощью',
#  'I10_32': 'Обращение за стоматологической помощью',
#  'I10_33': 'Получение необходимой стоматологической помощи',
#  'I10_34': 'Причины неполучения стоматологической помощи',
#  'I10_39': 'Курит ли респондент',
#  'I10_40': 'Возраст, когда начал курить',
#  'I10_41': 'Употребление алкогольных напитков',
#  'I10_42_01': 'Употребление  водки, коньяка и др. крепких напитков',
#  'I10_42_02': 'Употребление вина',
#  'I10_42_03': 'Употребление пива',
#  'I10_43': 'Подача заявления в Пенсионный Фонд на выдачу государственного сертификата на материнский капитал',
#  'I10_45': 'Воспользовались ли правом распоряжения средствами материнского капитала',
#  'I10_46_01': 'На улучшение жилищных условий',
#  'I10_46_02': 'На получение образования ребенком (детьми)',
#  'I10_46_03': 'На формирование накопительной части своей трудовой пенсии',
#  'I10_46_04': 'На приобретение товаров и услуг, предназначенных для социальной адаптации и интеграции в общество детей-инвалидов',
#  'I10_46_05': 'На ежемесячную выплату в связи с рождением (усыновлением) второго ребенка',
#  'I10_47_01': 'Да, указано в качестве единоличного владельца',
#  'I10_47_02': 'Да, указано в качестве совладельца наряду с другими лицами',
#  'I10_47_03': 'Нет, не указано',
#  'I10_47_04': 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ',
#  'I10_48_01': 'Считает ли надежными свои права собственности на землю в единоличном владении',
#  'I10_48_02': 'Считает ли надежными свои права собственности на землю в совладении',
#  'D01_011': 'Возраст ребенка в полных месяцах',
#  'D01_02': 'Код матери ребенка',
#  'D01_03': 'Код отца ребенка',
#  'D01_04': 'Родители ребенка лишены родительских прав',
#  'D01_05_01': 'Второй родитель (или оба родителя) проживает (проживают) в другом месте',
#  'D01_05_02': 'Второй родитель (или оба родителя) умер (умерли)',
#  'D01_05_03': 'Другой случай отсутствия одного или обоих родителей',
#  'D01_06_01': 'Находится ли ребенок под опекой',
#  'D01_06_03': 'Код опекуна ребенка',
#  'D01_07': 'Наличие ежемесячной выплаты в связи с отсутствием одного или обоих родителей',
#  'D01_071': 'Наличие дополнительного пособия по уходу за первым (вторым) ребенком в возрасте до 3 лет',
#  'D01_08': 'Оценка состояния здоровья своего ребенка',
#  'D01_082': 'Наличие у ребенка инвалидности в настоящее время',
#  'D01_09': 'Необходимость устройства ребенка в дошкольную образовательную организацию до достижения 3 лет',
#  'D01_10': 'Причина, по которой отсутствует необходимость в устройстве ребенка в дошкольную образовательную организацию',
#  'D01_11': 'Наличие нужной дошкольной образовательной организации для  ребенка вблизи дома',
#  'D01_12': 'Постановка на очередь для получения места в  дошкольной образовательной организации',
#  'D02_02': 'Код матери ребенка',
#  'D02_03': 'Код отца ребенка',
#  'D02_04': 'Родители ребенка лишены родительских прав',
#  'D02_05_01': 'Второй родитель (или оба родителя) проживает (проживают) в другом месте',
#  'D02_05_02': 'Второй родитель (или оба родителя) умер (умерли)',
#  'D02_05_03': 'Другой случай отсутствия одного или обоих родителей',
#  'D02_06_01': 'Находится ли ребенок под опекой',
#  'D02_06_03': 'Код опекуна ребенка',
#  'D02_07': 'Наличие ежемесячной выплаты в связи с отсутствием одного или обоих родителей',
#  'D02_08': 'Оценка состояния здоровья своего ребенка',
#  'D02_10': 'Назначение ребенку когда-либо инвалидности',
#  'D02_11': 'Наличие у ребенка инвалидности в настоящее время',
#  'D02_111': 'Вид ограничения жизнедеятельности (по которому назначена инвалидность)',
#  'D02_17_01': 'Болел ли ребенок в этом году с нахождением на постельном режиме',
#  'D02_17_02': 'Число месяцев, в которые ребенок болел',
#  'D02_18': 'Обращение в этом году за амбулаторно-поликлинической помощью для ребенка',
#  'D02_19': 'Получение мед. помощи для ребенка в последний раз обращения',
#  'D02_20_01': 'Время на запись к врачу (минут)',
#  'D02_20_02': 'Время на ожидание приема врача (минут)',
#  'D02_21': 'Год последнего посещения ребенком врача-стоматолога',
#  'D02_22': 'Вид дошкольной образовательной организации, посещаемой ребенком',
#  'D02_23': 'Причина непосещения ребенком дошкольной образовательной организации',
#  'D02_24_01': 'Поставлен ли ребенок на очередь для получения места в дошкольной образовательной организации',
#  'D02_24_02': 'Год постановки на очередь в дошкольную образовательную организацию',
#  'D02_25_01': 'Присмотр за ребенком осуществляет мать/отец',
#  'D02_25_02': 'Присмотр за ребенком осуществляют родители матери и/или отца',
#  'D02_25_03': 'Присмотр за ребенком осуществляют взрослые дети, другие члены домохозяйства',
#  'D02_25_04': 'Присмотр за ребенком осуществляют соседи, сторонние люди и др.',
#  'D02_25_05': 'Присмотр за ребенком осуществляет специально нанятый человек за плату',
#  'D02_25_06': 'Большую часть времени ребенок находится без присмотра взрослых лиц',
#  'D02_26': 'Каким образом ребенок обычно добирается до дошкольного образовательного учреждения из дома',
#  'D02_27': 'Время (минут) на дорогу от дома до дошкольной образовательной организации',
#  'D02_271': 'Возможность ребенку посещать мероприятия для детей один раз в месяц',
#  'D02_28_01': 'Посещал ли ребенок хотя бы раз кинотеатр',
#  'D02_28_02': 'Посещал ли ребенок хотя бы раз театр',
#  'D02_28_03': 'Посещал ли ребенок хотя бы раз зоопарк',
#  'D02_28_04': 'Посещал ли ребенок хотя бы раз цирк',
#  'D02_28_05': 'Посещал ли ребенок хотя бы раз музей',
#  'D02_28_06': 'Посещал ли ребенок хотя бы раз культурно-досуговое учреждение по месту жительства',
#  'D02_28_07': 'Ребенок не посещал ничего из перечисленного',
#  'D02_29': 'Посещение ребенок дополнительные занятия для развития своих способностей',
#  'D02_30_01': 'Посещают организованные занятия в спортивной секции (спортивной школе)',
#  'D02_30_02': 'Занимаются самостоятельно на спортивных сооружениях, участвуют в активных играх',
#  'D02_30_03': 'Не занимаются спортом и активными играми',
#  'D02_301_01': 'Занимаются спортом или активными играми почти каждый день',
#  'D02_301_02': 'Занимаются спортом или активными играми несколько раз в неделю, по выходным',
#  'D02_301_03': 'Занимаются спортом или активными играми несколько раз в месяц или реже',
#  'D02_31': 'Причина, по которой ребенок не занимается спортом',
#  'D02_32': 'Имел ли ребенок оплачиваемую работу в этом году',
#  'D02_33_01': 'Сколько часов в неделю ребенок обычно работает (или работал)',
#  'D02_33_02': 'МЕНЕЕ 1 ЧАСА В НЕДЕЛЮ',
#  'D02_34': 'Принимал ли ребенок участие в волонтерской деятельности в этом году',
#  'D02_35': 'Как часто ребенок занимался волонтёрской деятельностью',
#  'D03_02': 'Код матери ребенка',
#  'D03_03': 'Код отца ребенка',
#  'D03_04': 'Родители ребенка лишены родительских прав',
#  'D03_05_01': 'Второй родитель (или оба родителя) проживает (проживают) в другом месте',
#  'D03_05_02': 'Второй родитель (или оба родителя) умер (умерли)',
#  'D03_05_03': 'Другой случай отсутствия одного или обоих родителей',
#  'D03_06_01': 'Находится ли ребенок под опекой',
#  'D03_06_03': 'Код опекуна ребенка',
#  'D03_07': 'Наличие ежемесячной выплаты в связи с отсутствием одного или обоих родителей',
#  'D03_08': 'Оценка состояния здоровья своего ребенка',
#  'D03_10': 'Назначение ребенку когда-либо инвалидности',
#  'D03_11': 'Наличие у ребенка инвалидности в настоящее время',
#  'D03_111': 'Вид ограничения жизнедеятельности (по которому назначена инвалидность)',
#  'D03_17_01': 'Болел ли ребенок в этом году с нахождением на постельном режиме',
#  'D03_17_02': 'Число месяцев, в которые ребенок болел',
#  'D03_18': 'Обращение в этом году за амбулаторно-поликлинической помощью для ребенка',
#  'D03_19': 'Получение мед. помощи для ребенка в последний раз обращения',
#  'D03_20_01': 'Время на запись к врачу (минут)',
#  'D03_20_02': 'Время на ожидание приема врача (минут)',
#  'D03_21': 'Год последнего посещения ребенком врача-стоматолога',
#  'D03_23': 'Посещение ребенком общеобразовательной организации',
#  'D03_24': 'Форма обучения ребенка на дому',
#  'D03_25': 'Вид общеобразовательной организации, в которой учится ребенок',
#  'D03_251': 'Возможность обеспечить ребенка всем необходимым для школы',
#  'D03_26': 'Ребенок определен в обычный класс',
#  'D03_27': 'Посещает ли ребенок группу продленного дня',
#  'D03_28_01': 'Присмотр за ребенком осуществляет мать/отец',
#  'D03_28_02': 'Присмотр за ребенком осуществляют родители матери и/или отца',
#  'D03_28_03': 'Присмотр за ребенком осуществляют взрослые дети, другие члены домохозяйства',
#  'D03_28_04': 'Присмотр за ребенком осуществляют соседи, сторонние люди и др.',
#  'D03_28_05': 'Присмотр за ребенком осуществляет специально нанятый человек за плату',
#  'D03_28_06': 'Большую часть времени ребенок находится без присмотра взрослых лиц',
#  'D03_29': 'Вид собственности общеобразовательной организации, где учится ребенок',
#  'D03_30': 'Плата за обучение по базовой программе',
#  'D03_31': 'Местонахождение общеобразовательной организации',
#  'D03_32': 'Каким способом ребенок обычно добирается из дома до общеобразовательной организации',
#  'D03_33': 'Время (минут), которое тратит ребенок на дорогу от дома до общеобразовательной организации',
#  'D03_34': 'Посещение дополнительных занятий ребенком для развития своих способностей',
#  'D03_35_01': 'Посещают организованные занятия в спортивной секции (спортивной школе)',
#  'D03_35_02': 'Занимаются самостоятельно на спортивных сооружениях, участвуют в активных играх',
#  'D03_35_03': 'Не занимаются спортом и активными играми',
#  'D03_351_01': 'Занимаются спортом или активными играми почти каждый день',
#  'D03_351_02': 'Занимаются спортом или активными играми несколько раз в неделю, по выходным',
#  'D03_351_03': 'Занимаются спортом или активными играми несколько раз в месяц или реже',
#  'D03_36': 'Причина, по которой ребенок не занимается спортом',
#  'D03_37': 'Наличие у ребенка навыков работы с компьютером',
#  'D03_38': 'Пользуется ли ребенок выходом в Интернет',
#  'D03_39': 'Частота использования ребенком Интернета',
#  'D03_40_01': 'Цели выхода ребенка в Интернет: дистанционное обучение',
#  'D03_40_02': 'Цели выхода ребенка в Интернет: подготовка к урокам, школьным проектам',
#  'D03_40_03': 'Цели выхода ребенка в Интернет: общение в соц. Сетях',
#  'D03_40_04': 'Цели выхода ребенка в Интернет: развлечения',
#  'D03_40_05': 'Цели выхода ребенка в Интернет: не могу сказать определенно',
#  'D03_401': 'Возможность ребенку посещать мероприятия для детей один раз в месяц',
#  'D03_402_01': 'Участвовали в поездке продолжительностью менее суток за последние 12 месяцев',
#  'D03_402_02': 'Участвовали в поездке продолжительностью более суток за последние 12 месяцев',
#  'D03_402_03': 'Не участвовали в туристских или экскурсионных поездках за последние 12 месяцев',
#  'D03_402_04': 'Никогда не участвовали в  туристских или экскурсионных поездках',
#  'D03_402_05': 'Затруднились ответить, участвовали ли в туристских или экскурсионных поездках',
#  'D03_403_01': 'Участвовали за последние 12 месяцев в туристских или экскурсионных поездках по Российской Федерации',
#  'D03_403_02': 'Участвовали за последние 12 месяцев в туристских или экскурсионных поездках за пределы Российской Федерации',
#  'D03_41': 'Настрой на продолжение ребенком обучения после окончания общеобразовательной организации',
#  'D03_42': 'Наличие оплачиваемой работы у ребенка',
#  'D03_421_01': 'Сколько часов в неделю ребенок обычно работает (или работал) на этой работе',
#  'D03_421_02': 'МЕНЕЕ 1 ЧАСА В НЕДЕЛЮ',
#  'D03_43': 'Как распоряжался ребенок заработанными деньгами',
#  'D03_44': 'Помощь в собственном деле, оказанная ребенком',
#  'D03_45': 'Принимал ли ребенок участие в волонтерской деятельности в этом году',
#  'D03_451': 'Как часто ребенок занимался волонтёрской деятельностью',
#  'R_1': 'Место проживания',
#  'R_1_1': 'Размер населенного пункта',
#  'MONO': 'Монопрофильные города',
#  'ARK': 'Арктическая зона',
#  'KMN': 'Места традиционного проживания коренных малочисленных народов',
#  'FED_OKR': 'Федеральный округ',
#  'R_2_0': 'Состав домохозяйства',
#  'TIP_S': 'По наличию супружеских пар и детей в возрасте до 18 лет',
#  'MOL_SEM_1': 'Признак молодой семьи_16_25',
#  'R_2_4_1': 'Наличие молодой семьи_16_25',
#  'MNG_SEM': 'Признак многодетной семьи',
#  'R_2_5': 'Наличие многодетной семьи',
#  'NP_SEM': 'Признак неполной семьи',
#  'R_2_6': 'Наличие неполной семьи',
#  'MOL_SEM_D_1': 'Признак молодой семьи с детьми_16_25',
#  'R_2_7_1': 'Наличие молодой семьи с детьми_16_25',
#  'POL': 'Пол респондента',
#  'R_3_1': 'По возрастным (интервальным) группам респондентов',
#  'CH_UKR': 'Укрупненные возрастные группы',
#  'CHLICN': 'Число наличных лиц в домохозяйстве',
#  'DEN_NA_DUSHU': 'Денежный доход в среднем на члена ДХ, в месяц, рублей',
#  'CH_0_1_5': 'Дети до 1,5 лет',
#  'CH_1_5_3': 'Дети от 1,5 до 3 лет',
#  'CH_0_2': 'Дети до 3 лет',
#  'CH_0_8': 'Дети до 9 лет',
#  'CH_3_6': 'Дети 3-6 лет',
#  'CH_7_14': 'Дети 7-14 лет',
#  'CH_0_14': 'Дети до 15 лет',
#  'CH_0_15': 'Дети до 16 лет',
#  'CH_0_17': 'Дети до 18 лет',
#  'D_INV_0_17': 'Дети-инвалиды 0-17 лет',
#  'D_INV_3_17': 'Дети-инвалиды 3-17 лет',
#  'INV': 'Инвалид (всех возрастов)',
#  'ZAN': 'ЗАНЯТОСТЬ В ЭКОНОМИКЕ',
#  'GR_ZAN': 'По группам занятий респондентов',
#  'NAIM': 'По найму (не по найму)',
#  'SEKT': 'По сектору экономики',
#  'RAB_OSN': 'Основная категория работающих',
#  'P_O_ZAN': 'Пенсионер по занятости',
#  'INV_ZAN': 'Инвалид по занятости',
#  'OTP_DET': 'Лицо, находящееся в отпуске по уходу за ребенком до 1,5 лет',
#  'OTP_DET_OF': 'Лицо, находящееся в отпуске по уходу за ребенком до 1,5 лет (по статусу отпуска)',
#  'OTP_REB': 'Лицо, находящееся в отпуске по уходу за ребенком от 1,5 до 3 лет',
#  'OTP_REB_OF': 'Лицо, находящееся в отпуске по уходу за ребенком от 1,5 до 3 лет (по статусу отпуска)',
#  'HAVE_D_14': 'Лица (мать, отец), имеющие совместно проживающих детей в возрасте до 15 лет',
#  'HAVE_D_14_INV': 'Лица (мать, отец), имеющие совместно проживающих детей-инвалидов в возрасте до 15 лет',
#  'HAVE_D_2': 'Лица (мать, отец), имеющие совместно проживающих детей в возрасте до 3 лет',
#  'HAVE_D_1_5': 'Лица (мать, отец), имеющие совместно проживающих детей в возрасте до 1,5 лет',
#  'HAVE_D_1_5_3': 'Лица (мать, отец), имеющие совместно проживающих детей в возрасте от 1,5 до 3 лет',
#  'BEZ_PAP': 'Лица (мать, отец), имеющие совместно проживающих детей в возрасте до 15 лет и воспитывающие детей без супруга (и)',
#  'UCH': 'Лица, обучающиеся в образовательных организациях',
#  'PENS': 'Пенсионер (в возрасте 15 лет и более)',
#  'PENS_UST': 'Лица, получающие пенсию, назначенную в год достижения общеустановленного пенсионного возраста',
#  'PENS_RAN': 'Лица, получающие пенсию, назначенную ранее достижения общеустановленного пенсионного возраста',
#  'DX': '65_DX',
#  'V598': '75_DX',
#  'GL_DH': 'Признак главы ДХ',
#  'GL_DH_VOZR': 'Возрастная группа главы ДХ',
#  'GL_DH_SUPR': 'Супруг (а) главы ДХ',
#  'DOX_mean': 'Средний доход домохозяйства, в месяц, рублей',
#  'PM_DET': 'Величина прожиточного минимума на ребенка',
#  'PM_TRUD': 'Величина прожиточного минимума на трудоспособного',
#  'PM_PENS': 'Величина прожиточного минимума на пенсионера',
#  'PM_DX_MES': 'ВПМ на ДХ, месяц (рублей)',
#  'PM_DX_SRED_MES': 'ВПМ на члена ДХ, месяц (рублей)',
#  'MALOIM': 'Признак малоимущего населения',
#  'KVZV': 'Коэффициент взвешивания_основной',
#  'DLIT_OTP': 'Продолжительность нахождения в отпуске по уходу за ребенком, месяцев',
#  'ROD_NER_INV': 'Ребенок в возрасте 0-15 лет, проживающий в семье, где один или оба родителя являются неработающими инвалидами',
#  'ROD_BEZR': 'Ребенок в возрасте до 15 лет, проживающий в семьях, где один или оба родителя являются безработными',
#  'ROD_UCH_OCH': 'Ребенок в возрасте до 15 лет, проживающий в семьях, где один или оба родителя являются учащимися очной формы обучения',
#  'ROD_ALK': 'Ребенок в возрасте до 15 лет, проживающий в семьях, где один или оба родителя употребляют алкогольные напитки несколько раз в неделю или прак',
#  'NAL_ROD': 'Дети в возрасте до 15 лет по наличию родителей',
#  'SIROT': 'Дети-сироты (без обоих родителей) в возрасте до 15 лет'}

# %%
selection = [
    'I02_03_10', # 'Плохая организация работы общественного транспорта' 
    'I02_03_12', # 'Существуют проблемы с состоянием дорог, безопасностью дорожного движения в населенном пункте',
    'I03_01_01', # 'Регулярное использование общественного городского (пригородного) муниципального транспорта',
    'I03_01_02',# 'Регулярное использование общественного городского (пригородного) коммерческого транспорта',
    'I03_01_03', # 'Регулярное использование электропоезда, пригородного поезда',
    'I03_01_041', # 'Регулярное использование собственного автомобиля, мотоцикла (в качестве водителя)',
    'I03_01_05', #'Регулярное использование автомобиля, мотоцикла (в качестве пассажира)',
    "H00_02", # код субъекта РФ
    ]

# %%
def descriptional_statistics(df, meta, selection):
    # Создадим новую таблицу (pandas DataFrame), но только с теми колонками,
    # которые используются в расчётах.
    # Так используется меньше памяти, удобнее визуализировать. Но можно пользоваться и исходной таблицей.
    selected = df[selection]
    # Используем генератор списков, чтобы переименовать служебные заголвки в читаемые.
    # для этого мы хотим "пройтись" по всем меткам в списке selection и получить новый список вместо selection.
    # Подробнее о генераторах списков: https://pythontutor.ru/lessons/lists/#section_3
    selection_names = [meta.column_names_to_labels[label] for label in selection]
    # Заменим исходные наименования колонок на наименования из получившегося списка selection_names, 
    # теперь у нас наименования колонок будет как в столбце "метки" файла sav.
    selected.columns = selection_names
    # 98 - код Республики Саха (Якутии), согласно ОКВЭДам.
    # создаем маску, чтобы получить таблицу с данными только по Якутии.
    mask = selected['Код субъекта РФ'] == '98'
    # применяем маску - используем только те строчки, где значения маски True
    region = selected[mask]
    # число наблюдений в таблице получаем через атрибут shape.
    # так как в shape находится объект типа кортеж (tuple)- структура данных, похожая на список,
    # но неизменяемая (чтобы добавить или удалить элемент, придется создавать новый объект типа кортеж в памяти).
    # из кортежа,  так же, как из списка, можно получить по порядковому индексу его элемент
    # в данном случае у нас shape[0] - количество строк, shape[1] - количество столбцов.
    # pandas DataFrame - двумерная таблица, ее размерность описывается количеством строчек и столбцов.
    # одномерная "таблица" pandas, по сути, одна колонка, размерность которой описывается только количеством строчек,
    # называется Series

    print(f"Количество наблюдений по выбранным переменным: {region.shape[0]}")
    # apply - метод pandas DataFrame, который позволяет применить функцию ко всему Series или DataFrame,
    # не прописывая цикл явно.

    # Применим функцию, который переведет служебные значения в читаемые ко всему столбцу Размер населенного пункта.

    # в python есть два способа объявить функцию - через ключевое слово def или lambda.
    # def удобно использовать, когда у функции много аргументов и/или в ней выполняется много действий
    # lambda удобно использовать, когда функция принимает 1-2 аргумента и выполняемые действия можно прописать в 
    # одну строчку

    # После ключевого слова lambda идет аргумент функции (x), двоеточие и после него прописываем действие 
    # над аргументом х

    # В данном случае необходимо из словаря variable_to_label получить значение ключа,
    # а затем по этому значению получить другое значение 
    # из словаря value_labels
    # т.е., value_labels это вложенный словарь - словарь в словаре.
    for name, variable in zip(selection_names[:-1], selection[:-1]):
        print(name)
        if region[name].dropna().shape[0] > 0: 
            if (variable != 'DEN_NA_DUSHU') and not ('(общая площадь)' in name): # доходы и вопросы с общей площадью не по номинальной шкале, так что их преобразовывать не надо
                

                possible_answers = meta.value_labels[meta.variable_to_label[variable]]
                possible_answers_str = {}
                for k, v in possible_answers.items():
                    possible_answers_str[str(k)] = v # бывает так, что в этом словаре часть ключей имеет тип данных float, а часть строка
                
                print(f"Возможные ответы: {possible_answers_str}")
                try: 
                    variable_values = region[name].apply(lambda x: possible_answers_str[str(x)] if not np.isnan(x) else x)
                except KeyError:
                    print("Варианты ответа отсутствуют в словаре возможных ответов. Посчитать осмысленные описательные статистики нельзя")
                    print(f"Варианты ответа: {region[name].unique()}")
                    print("--------------------------")
                    continue
                print(variable_values.describe())
            else:
                print(region[name].describe())
            
        else:
            print("Нет данных")
        print("--------------------------")

# %% [markdown]
# Что считает метод describe для нечисловых данных:
#
# unique - количество уникальных значений
#
# top - наиболее часто встречающееся значение
#
# freq - частота top-а (мода)
#
# в случае нескольких одинаковых top-ов, какой вывести, выбирается случайно

# %%
print("2020 ГОД")
descriptional_statistics(df_2020, meta_2020, selection)
# Out:
# 2020 ГОД
# Количество наблюдений по выбранным переменным: 1178
# Плохая организация работы общественного транспорта
# Возможные ответы: {'-7.0': 'Затруднились ответить', '1.0': 'Да', '2.0': 'Нет'}
# count     886
# unique      3
# top       Нет
# freq      673
# Name: Плохая организация работы общественного транспорта, dtype: object
# --------------------------
# Существуют проблемы с состоянием дорог, безопасностью дорожного движения в населенном пункте
# Возможные ответы: {'-7.0': 'Затруднились ответить', '1.0': 'Да', '2.0': 'Нет'}
# count     886
# unique      3
# top       Нет
# freq      516
# Name: Существуют проблемы с состоянием дорог, безопасностью дорожного движения в населенном пункте, dtype: object
# --------------------------
# Регулярное использование общественного городского (пригородного) муниципального транспорта
# Возможные ответы: {'1.0': 'Регулярное использование общественного городского (пригородн'}
# count                                                   150
# unique                                                    1
# top       Регулярное использование общественного городск...
# freq                                                    150
# Name: Регулярное использование общественного городского (пригородного) муниципального транспорта, dtype: object
# --------------------------
# Регулярное использование общественного городского (пригородного) коммерческого транспорта
# Возможные ответы: {'2.0': 'Регулярное использование общественного городского (пригородн'}
# count                                                    75
# unique                                                    1
# top       Регулярное использование общественного городск...
# freq                                                     75
# Name: Регулярное использование общественного городского (пригородного) коммерческого транспорта, dtype: object
# --------------------------
# Регулярное использование электропоезда, пригородного поезда
# Нет данных
# --------------------------
# Регулярное использование собственного автомобиля, мотоцикла (в качестве водителя)
# Возможные ответы: {'4.0': 'Регулярное использование собственного автомобиля, мотоцикла'}
# count                                                   249
# unique                                                    1
# top       Регулярное использование собственного автомоби...
# freq                                                    249
# Name: Регулярное использование собственного автомобиля, мотоцикла (в качестве водителя), dtype: object
# --------------------------
# Регулярное использование автомобиля, мотоцикла (в качестве пассажира)
# Возможные ответы: {'5.0': 'Регулярное использование автомобиля, мотоцикла (в качестве п'}
# count                                                   156
# unique                                                    1
# top       Регулярное использование автомобиля, мотоцикла...
# freq                                                    156
# Name: Регулярное использование автомобиля, мотоцикла (в качестве пассажира), dtype: object
# --------------------------
